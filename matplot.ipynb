# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib import style 
# %matplotlib inline

# %%
randomNumber=np.random.rand(10)

# %%
print (randomNumber)
# Out:
# [0.38645811 0.22749866 0.37078103 0.21041944 0.32496813 0.19696794
#  0.33393455 0.42011164 0.23777843 0.9073996 ]

# %%
style.use('ggplot')

plt.plot(randomNumber,'g',label='line one',linewidth=4)

plt.xlabel('Range')

plt.ylabel('Number')

plt.title('First Plot')

plt.legend()
plt.show()

# %%
#problem statement

import matplotlib.pyplot as ptd

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
cause = 'a','b','c','d','e','f'
percentile=[62,5,4,2,1,26]

# %%
plt.figure(figsize=(10,10))
explode=(0.05,0,0,0,0,0)
plt.pie(percentile,labels=cause,explode=explode,autopct='%1.1f%%',startangle=70)
plt.axis('equal')
plt.title('ohio state')
plt.show()

# %%
d={'a':10,'b':20,'c':30}

# %%
plt.bar(x=d.keys(),height=d.values())
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(x=d.values(),labels=d.keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x1f4a34a0640>,
#   <matplotlib.patches.Wedge at 0x1f4a34a0a30>,
#   <matplotlib.patches.Wedge at 0x1f4a34a0ee0>],
#  [Text(0.9526279355804298, 0.5500000148652441, 'a'),
#   Text(-0.5500000594609755, 0.9526279098330699, 'b'),
#   Text(1.0298943251329445e-07, -1.0999999999999954, 'c')])

# %%
plt.plot(['values'])

# %%
import pandas as pd

# %%
df=pd.read_csv('Quote-Equity-ADANIPORTS-EQ-04-10-2023-to-11-10-2023.csv',parse_dates=True)

# %%
df.head()
# Out:
#          Date  series    OPEN   HIGH     LOW   PREV. CLOSE    ltp   close   \
# 0  11-Oct-2023      EQ  827.40  827.4  812.35        819.50  819.0  814.85
# 1  10-Oct-2023      EQ  800.55  823.7  800.55        790.05  818.0  819.50
# 2  09-Oct-2023      EQ  815.00  818.8  785.00        830.75  788.5  790.05
# 3  06-Oct-2023      EQ  830.00  836.5  826.40        825.20  830.5  830.75
# 4  05-Oct-2023      EQ  830.85  832.0  820.25        824.60  825.0  825.20
#
#     vwap   52W H   52W L     VOLUME              VALUE  No of trades
# 0  819.05   916.0   395.1  32,81,387  2,68,76,34,855.40        51,448
# 1  815.04   916.0   395.1  75,91,327  6,18,72,02,862.60      1,20,651
# 2  798.65   916.0   395.1  59,94,282  4,78,73,36,779.10      1,20,240
# 3  831.14   916.0   395.1  18,77,058  1,56,01,07,338.60        38,610
# 4  825.31   916.0   395.1  20,83,505  1,71,95,28,767.40        52,617
