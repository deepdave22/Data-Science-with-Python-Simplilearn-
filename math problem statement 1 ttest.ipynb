# %%
# problem statement ttest

# %%
import math

# %%
def norm_vector(v):
    dot_product=sum(i*i for i in v)
      return math.sqrt(dot_product)
norm_vector(-1,-2,3,4,5)
# Out:
#   Cell In [4], line 3
#     return math.sqrt(dot_product)
#     ^
# IndentationError: unexpected indent

# %%
def matrix_addition (x,y):
    xrows=len(x)
    xcols=len()

# %%
import random
a=[random.gauss(50,20) for x in range(30)]
b=[random.gauss(55,15) for x in range(30)]

# %%
import seaborn as sns

# %%
sns.set_style('darkgrid')
sns.kdeplot(a,fill=True)
sns.kdeplot(b,fill=True)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
import scipy.stats as stats

# %%
t_stat,p_value=stats.ttest_ind(a,b,equal_var=False)

# %%
t_stat,p_value
# Out:
# (-2.2722047095564073, 0.02698227112662652)

# %%
import numpy as np

# %%
np.mean(a),np.mean(b)
# Out:
# (45.04324955284312, 54.45470361303588)

# %%
a=[random.gauss(50,20) for x in range(30)]
b=[random.gauss(60,25) for x in range(30)]

# %%
t_stat,p_value
# Out:
# (-2.2722047095564073, 0.02698227112662652)

# %%
np.mean(b)-np.mean(a)
# Out:
# 11.727786507055512

# %%
np.mean(a)
# Out:
# 53.87581130571836

# %%
t_stat,p_values=stats.ttest_lsamp(a,50,axis=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 t_stat,p_values=stats.ttest_lsamp(a,50,axis=0)
#
# AttributeError: module 'scipy.stats' has no attribute 'ttest_lsamp'
