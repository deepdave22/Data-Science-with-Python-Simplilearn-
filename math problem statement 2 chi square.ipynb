# %%
import numpy as np

# %%
data1=np.random.chisquare(df=1,size=1000)
data2=np.random.chisquare(df=2,size=1000)
data3=np.random.chisquare(df=3,size=1000)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(data1,hist=False,label='dof 1')
sns.distplot(data2,hist=False,label='dof 2')
sns.distplot(data3,hist=False,label='dof 3')
plt.legend()
# Out:
# C:\Users\daved\AppData\Local\Temp\ipykernel_9268\595903177.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1,hist=False,label='dof 1')
# C:\Users\daved\AppData\Local\Temp\ipykernel_9268\595903177.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2,hist=False,label='dof 2')
# C:\Users\daved\AppData\Local\Temp\ipykernel_9268\595903177.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data3,hist=False,label='dof 3')

# %%
from scipy.stats import cgi2_contigency
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 from scipy.stats import cgi2_contigency
#
# ImportError: cannot import name 'cgi2_contigency' from 'scipy.stats' (C:\Python310\lib\site-packages\scipy\stats\__init__.py)

# %%
from scipy.stats import chi2_contigency
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 from scipy.stats import chi2_contigency
#
# ImportError: cannot import name 'chi2_contigency' from 'scipy.stats' (C:\Python310\lib\site-packages\scipy\stats\__init__.py)
